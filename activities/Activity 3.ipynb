# %% [markdown]
# ## ⚛️ Data Science - Training Activities ⚙️ (Activity N° 3)

# %% [markdown]
# #### *By: Jiliar Silgado Cardona*

# %% [markdown]
# ✅ [***LinkedIn***](https://www.linkedin.com/in/jiliar-silgado-cardona-4b970b286/)

# %% [markdown]
# ✅ [***GitHub***](https://github.com/Jiliar)

# %% [markdown]
# ### 💡Introduction to the Activity Report: Dataframes and Data Visualization

# %% [markdown]
# This report presents the results of one key activities focused on data analysis, data visualization and manipulation. The activity involved using Jupyter Notebook to work with a given dataset, applying specific functions to explore and clean the variables it contains.

# %% [markdown]
# #### General Resources for Solutions:

# %% [markdown]
# This report presents the results of one key activities focused on data analysis and manipulation. The activity involved using Jupyter Notebook to work with a given dataset, applying specific functions to explore and clean the variables it contains.

# %% [markdown]
# ##### Functions

# %%
# Pandas Importing
import pandas as pd 

def get_file_details(file):

    # Reading the CSV file into a DataFrame, with the specified column set as the index.
    df = pd.read_csv(file)  

    # Stripping leading and trailing spaces from the column headers.
    df.columns = df.columns.str.strip()

    # Returning the cleaned DataFrame.
    return df

# %% [markdown]
# ### Activity 1: Filters and Crossovers

# %% [markdown]
# #### ✍️ Statement

# %% [markdown]
# Write blocks of code and Markdown in a Jupyter HTML file where variables are taken from a given database and the following is done to them:
#
# + Data type transformation.
# + Table crossing.
# + Variable filtering by some type of criterion.

# %% [markdown]
# #### 📥 Input:

# %% [markdown]
# ***Download File Orders:*** [Orders](../data/csv/act3_orders.csv)

# %% [markdown]
# ***Download File Details:*** [Details](../data/csv/act3_details.csv)

# %%
input1 = "../data/csv/act3_c_orders.csv" # Specify the path to the CSV file.

# Call the get_file_details function, passing in the file path and setting the first column (index 0) as the index.
# Use the .head() method to display the first 5 rows of the DataFrame.
df1 = get_file_details(input1)
df1.head()
# Out:
#   Order ID  Order Date CustomerName           State     City
# 0  B-26055  10-03-2018    Harivansh   Uttar Pradesh  Mathura
# 1  B-25993  03-02-2018       Madhav           Delhi    Delhi
# 2  B-25973  24-01-2018  Madan Mohan   Uttar Pradesh  Mathura
# 3  B-25923  27-12-2018        Gopal     Maharashtra   Mumbai
# 4  B-25757  21-08-2018     Vishakha  Madhya Pradesh   Indore

# %%
input2 = "../data/csv/act3_c_details.csv" # Specify the path to the CSV file.

# Call the get_file_details function, passing in the file path and setting the first column (index 0) as the index.
# Use the .head() method to display the first 5 rows of the DataFrame.
df2 = get_file_details(input2)
df2.head()
# Out:
#   Order ID  Amount  Profit  Quantity     Category      Sub-Category  \
# 0  B-25681    1096     658         7  Electronics  Electronic Games
# 1  B-26055    5729      64        14    Furniture            Chairs
# 2  B-25955    2927     146         8    Furniture         Bookcases
# 3  B-26093    2847     712         8  Electronics          Printers
# 4  B-25602    2617    1151         4  Electronics            Phones
#
#    PaymentMode
# 0          COD
# 1          EMI
# 2          EMI
# 3  Credit Card
# 4  Credit Card

# %% [markdown]
# ### ⚙️ Data Processing:
# ####  Data Merging:

# %%
df = pd.merge(df1, df2, on='Order ID') # Merge df1 and df2 on the 'Order ID' column
df
# Out:
#      Order ID  Order Date CustomerName             State     City  Amount  \
# 0     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura    5729
# 1     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura     671
# 2     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura     443
# 3     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura      57
# 4     B-26055  10-03-2018    Harivansh     Uttar Pradesh  Mathura     227
# ...       ...         ...          ...               ...      ...     ...
# 1495  B-25742  03-08-2018       Ashwin               Goa      Goa      11
# 1496  B-26088  26-03-2018       Bhavna            Sikkim  Gangtok      11
# 1497  B-25707  01-07-2018      Shivani       Maharashtra   Mumbai       8
# 1498  B-25758  22-08-2018      Shubham  Himachal Pradesh    Simla       8
# 1499  B-26095  28-03-2018      Monisha         Rajasthan   Jaipur       6
#
#       Profit  Quantity     Category Sub-Category  PaymentMode
# ...

# %%
df.dtypes #Showing Data Types
# Out:
# Order ID        object
# Order Date      object
# CustomerName    object
# State           object
# City            object
# Amount           int64
# Profit           int64
# Quantity         int64
# Category        object
# Sub-Category    object
# PaymentMode     object
# dtype: object

# %%
import cast_data_lib as cast
df = cast.casting_data(df, 'Order Date', 'date') # Casting Order Date to datetime
df.dtypes
# Out:
# Order ID                object
# Order Date      datetime64[ns]
# CustomerName            object
# State                   object
# City                    object
# Amount                   int64
# Profit                   int64
# Quantity                 int64
# Category                object
# Sub-Category            object
# PaymentMode             object
# dtype: object

# %%
import clean_data_lib as cle
cle.find_special_characters(df) # Determine if there are any string fields that need to be cleared.
# Out:
# {'Order ID': {'-'},
#  'Order Date': {'-'},
#  'Profit': {'-'},
#  'Sub-Category': {'-'}}

# %% [markdown]
# The Data Frame has no special characters to handle.

# %%
#Filtering Orders by Criteria: Order Date (Month: January , Year: 2023) and PaymentMode: Credit Card
filtered_df = df[(df['Order Date'].dt.month == 1) & (df['Order Date'].dt.year == 2018) & (df['PaymentMode'] == 'Credit Card')]
filtered_df
# Out:
#      Order ID Order Date CustomerName           State       City  Amount  \
# 59    B-25798 2018-01-10       Shishu  Andhra Pradesh  Hyderabad      38
# 61    B-25602 2018-01-04       Vrinda     Maharashtra       Pune    2617
# 65    B-25602 2018-01-04       Vrinda     Maharashtra       Pune     119
# 310   B-25601 2018-01-04       Bharat         Gujarat  Ahmedabad       8
# 998   B-25989 2018-01-02       Anjali           Delhi      Delhi     330
# 1000  B-25989 2018-01-02       Anjali           Delhi      Delhi      44
# 1450  B-25709 2018-01-07    Aakanksha  Madhya Pradesh     Indore      41
# 1477  B-25841 2018-01-11      Ashvini     Maharashtra     Mumbai      22
#
#       Profit  Quantity     Category Sub-Category  PaymentMode
# 59       -13         3     Clothing        Stole  Credit Card
# 61      1151         4  Electronics       Phones  Credit Card
# 65        -5         8     Clothing        Saree  Credit Card
# 310       -2         3     Clothing  Hankerchief  Credit Card
# ...

# %% [markdown]
# ### ✅ Activity 2: Data Visualization

# %% [markdown]
# #### ✍️ Statement:

# %% [markdown]
# Write blocks of code and Markdown in a Jupyter html file where variables are taken from a given database and the following is done to them:
#
# + Identification and some transformation of the data type.
# + Filter variables by some type of criterion.
# + Use at least 2 types of graphics for selected variables.

# %% [markdown]
# #### 📥 Input:

# %% [markdown]
# ***Download File student-mat:*** [student-mat](../data/csv/act3_b_student-mat.csv)

# %% [markdown]
# ***Download File student-por:*** [student-por](../data/csv/act3_b_student-por.csv)

# %%
input3 = "../data/csv/act3_b_student-mat.csv" # Specify the path to the CSV file.

# Call the get_file_details function, passing in the file path and setting the first column (index 0) as the index.
# Use the .head() method to display the first 5 rows of the DataFrame.
df3 = get_file_details(input3)
df3['type'] = 'Math'
print(df3.shape)
df3.head()
# Out:
# (395, 34)
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3  type
# 0        3     4     1     1       3        6   5   6   6  Math
# 1        3     3     1     1       3        4   5   5   6  Math
# 2        3     2     2     3       3       10   7   8  10  Math
# 3        2     2     1     1       5        2  15  14  15  Math
# 4        3     2     1     2       5        4   6  10  10  Math
#
# [5 rows x 34 columns]

# %%
input4 = "../data/csv/act3_b_student-por.csv" # Specify the path to the CSV file.

# Call the get_file_details function, passing in the file path and setting the first column (index 0) as the index.
# Use the .head() method to display the first 5 rows of the DataFrame.
df4 = get_file_details(input4)
df4['type'] = 'Portuguese Lang'
print(df4.shape)
df4.head()
# Out:
# (649, 34)
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   freetime goout  Dalc  Walc  health absences  G1  G2  G3             type
# 0        3     4     1     1       3        4   0  11  11  Portuguese Lang
# 1        3     3     1     1       3        2   9  11  11  Portuguese Lang
# 2        3     2     2     3       3        6  12  13  12  Portuguese Lang
# 3        2     2     1     1       5        0  14  14  14  Portuguese Lang
# 4        3     2     1     2       5        0  11  13  13  Portuguese Lang
#
# [5 rows x 34 columns]

# %%
df5 = pd.concat([df3, df4], ignore_index=True) # Concat df1 and df2
print(df5.shape)
df5
# Out:
# (1044, 34)
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
df5.dtypes
# Out:
# school        object
# sex           object
# age            int64
# address       object
# famsize       object
# Pstatus       object
# Medu           int64
# Fedu           int64
# Mjob          object
# Fjob          object
# reason        object
# guardian      object
# traveltime     int64
# studytime      int64
# failures       int64
# schoolsup     object
# famsup        object
# paid          object
# activities    object
# nursery       object
# higher        object
# internet      object
# romantic      object
# famrel         int64
# freetime       int64
# goout          int64
# Dalc           int64
# Walc           int64
# health         int64
# absences       int64
# G1             int64
# G2             int64
# G3             int64
# type          object
# dtype: object

# %%
cle.find_special_characters(df5) # Determine if there are any string fields that need to be cleared.
# Out:
# {'Mjob': {'_'}, 'Fjob': {'_'}}

# %%
#Filtering and grouping alcohol consumption by school and sex.
grouped_df = df.groupby(['school', 'sex']).size().unstack(fill_value=0)
grouped_df
# Out:
# sex       F    M
# school
# GP      420  352
# MS      171  101

# %% [markdown]
# Graph of filtering and grouping of alcohol consumption by school and sex.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Configure the graph
fig, ax = plt.subplots(figsize=(8, 6))

# Define the width of the bars
bar_width = 0.35

# Positions for the bars on the x axis
index = np.arange(len(grouped_df))

# Get the column values, with a default value of 0 if they do not exist
male_counts = grouped_df.get('M', pd.Series(0, index=grouped_df.index))
female_counts = grouped_df.get('F', pd.Series(0, index=grouped_df.index))

# Add tags and title
bar1 = ax.bar(index, male_counts, bar_width, label='Male', alpha=0.5)
bar2 = ax.bar(index + bar_width, female_counts, bar_width, label='Female', alpha=0.5)

# Add tags and title
ax.set_xlabel('School')
ax.set_ylabel('Count')
ax.set_title('Count of Records by School and Sex')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(grouped_df.index)
ax.legend()

# Show
plt.show()

# %% [markdown]
# ### ✍️ Conclusion

# %% [markdown]
# The data reflect alcohol consumption among students at two schools, GP and MS. At both schools, female students report higher alcohol consumption than male students. Specifically, at GP, 420 cases of alcohol consumption were recorded among female students, compared to 352 cases of alcohol consumption among male students. Similarly, at MS, female students reported 171 cases of alcohol consumption, while male students reported 101. This suggests that alcohol consumption is higher among female students at both schools.
#
# This relationship can be seen in the fact that there are more female students enrolled at both schools than male students and that GP has a larger student population than MS.s.

# %%
grouped_df  = df5.groupby(['school', 'age']).size().reset_index(name='count')
gp_data = grouped_df[['age', 'count']][grouped_df['school'] == 'GP']
ms_data = grouped_df[['age', 'count']][grouped_df['school'] == 'MS']

# %%
# Configurar el gráfico de líneas
plt.figure(figsize=(10, 6))

# Graficar la primera línea para la escuela 'GP'
plt.plot(gp_data['age'], gp_data['count'], marker='o', linestyle='-', label='GP', color='blue')

# Graficar la segunda línea para la escuela 'MS'
plt.plot(ms_data['age'], ms_data['count'], marker='o', linestyle='-', label='MS', color='green')

# Añadir etiquetas y título
plt.xlabel('Age')
plt.ylabel('Number of Students')
plt.title('Alcohol Consumption by Age and School')
plt.legend()

# Mostrar el gráfico
plt.grid(True)
plt.show()

# %% [markdown]
# ### ✍️ Conclusion

# %% [markdown]
# The data indicates that students aged 15 to 18 in both schools exhibit high levels of alcohol consumption. However, this behavior starts to decline after the age of 19.
# This trend may be attributed to the developmental stage of adolescence, during which peer influence and social experimentation often lead to increased alcohol consumption. As students transition into young adulthood, they may develop a greater sense of responsibility and face new life challenges that can contribute to reduced drinking behavior.

# %%
#Filtering Alcohol Consumption by Criteria: age
grouped_df  = df5.groupby(['age']).size().reset_index(name='count')
grouped_df.sort_values(by='count', ascending=False)
# Out:
#    age  count
# 1   16    281
# 2   17    277
# 3   18    222
# 0   15    194
# 4   19     56
# 5   20      9
# 6   21      3
# 7   22      2

# %%
plt.figure(figsize=(8, 8))
plt.pie(grouped_df['count'], labels=grouped_df['age'], autopct='%1.1f%%')
plt.title('Alcohol Consumption by Age (GP)')
plt.legend(grouped_df['age'], title='Ages', loc='upper left')
plt.show()

# %% [markdown]
# ### ✍️ Conclusion

# %% [markdown]
# The data reveals a notable pattern in alcohol consumption among students across different ages. The highest levels of consumption are observed in students aged 15 to 18, with a significant decrease in consumption as students age. Specifically:
#
# + Students aged 15 have the highest consumption with a count of 194.
# + Consumption remains high for students aged 16 (281) and 17 (277), and slightly drops for students aged 18 (222).
# + A sharp decline is evident from age 19 onward, with consumption dropping to 56 for age 19, and further decreasing to minimal levels by ages 20 (9), 21 (3), and 22 (2).
#
# This trend suggests that alcohol consumption among students peaks during mid-adolescence and decreases significantly as they transition into young adulthood.
